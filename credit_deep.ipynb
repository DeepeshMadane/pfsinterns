# %% [markdown]
# # Importing libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('creditcard.csv')

# %%
df.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
df.isnull().values.any()
# Out:
# False

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# std    1.380247e+00  1.332271e+00  1.237094e+00  1.194353e+00  1.098632e+00
# min   -1.137433e+02 -2.616051e+01 -4.355724e+01 -7.321672e+01 -1.343407e+01
# 25%   -6.915971e-01 -7.682956e-01 -5.540759e-01 -2.086297e-01 -6.430976e-01
# 50%   -5.433583e-02 -2.741871e-01  4.010308e-02  2.235804e-02 -5.142873e-02
# 75%    6.119264e-01  3.985649e-01  5.704361e-01  3.273459e-01  5.971390e-01
# max    3.480167e+01  7.330163e+01  1.205895e+02  2.000721e+01  1.559499e+01
#
#        ...           V21           V22           V23           V24  \
# count  ...  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   ...  1.654067e-16 -3.568593e-16  2.578648e-16  4.473266e-15
# std    ...  7.345240e-01  7.257016e-01  6.244603e-01  6.056471e-01
# min    ... -3.483038e+01 -1.093314e+01 -4.480774e+01 -2.836627e+00
# 25%    ... -2.283949e-01 -5.423504e-01 -1.618463e-01 -3.545861e-01
# 50%    ... -2.945017e-02  6.781943e-03 -1.119293e-02  4.097606e-02
# 75%    ...  1.863772e-01  5.285536e-01  1.476421e-01  4.395266e-01
# max    ...  2.720284e+01  1.050309e+01  2.252841e+01  4.584549e+00
#
#                 V25           V26           V27           V28         Amount  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  284807.000000
# mean   5.340915e-16  1.683437e-15 -3.660091e-16 -1.227390e-16      88.349619
# std    5.212781e-01  4.822270e-01  4.036325e-01  3.300833e-01     250.120109
# min   -1.029540e+01 -2.604551e+00 -2.256568e+01 -1.543008e+01       0.000000
# 25%   -3.171451e-01 -3.269839e-01 -7.083953e-02 -5.295979e-02       5.600000
# 50%    1.659350e-02 -5.213911e-02  1.342146e-03  1.124383e-02      22.000000
# 75%    3.507156e-01  2.409522e-01  9.104512e-02  7.827995e-02      77.165000
# max    7.519589e+00  3.517346e+00  3.161220e+01  3.384781e+01   25691.160000
#
#                Class
# count  284807.000000
# mean        0.001727
# std         0.041527
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
#
# [8 rows x 31 columns]

# %% [markdown]
# # Checking null values

# %%
df.isnull().values.any()
# Out:
# False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
#  20  V20     284807 non-null  float64
#  21  V21     284807 non-null  float64
#  22  V22     284807 non-null  float64
#  23  V23     284807 non-null  float64
#  24  V24     284807 non-null  float64
#  25  V25     284807 non-null  float64
#  26  V26     284807 non-null  float64
#  27  V27     284807 non-null  float64
#  28  V28     284807 non-null  float64
#  29  Amount  284807 non-null  float64
#  30  Class   284807 non-null  int64
# dtypes: float64(30), int64(1)
# memory usage: 67.4 MB

# %% [markdown]
# # Handling missing values

# %%
missing_values = df.isnull().sum()

# %%
df.dropna(inplace=True)

df['V1'].fillna(df['V1'].mean(), inplace=True)

df['V2'].fillna(0, inplace=True)

# %%
missing_values = df.isnull().sum()

# %%
missing_values
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
df.isnull().values.any()
# Out:
# False

# %%
count_classes = pd.value_counts(df['Class'], sort = True).sort_index()
count_classes.plot(kind = 'bar')
plt.title("Fraud class histogram")
plt.xlabel("Class")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
Fraud = df[df['Class']==1]
Normal = df[df['Class']==0]

# %%
pd.concat([Normal.Amount.describe(), Normal.Time.describe()],  axis=1)
# Out:
#               Amount           Time
# count  284315.000000  284315.000000
# mean       88.291022   94838.202258
# std       250.105092   47484.015786
# min         0.000000       0.000000
# 25%         5.650000   54230.000000
# 50%        22.000000   84711.000000
# 75%        77.050000  139333.000000
# max     25691.160000  172792.000000

# %%
pd.concat([Fraud.Amount.describe(), Fraud.Time.describe()],  axis=1)
# Out:
#             Amount           Time
# count   492.000000     492.000000
# mean    122.211321   80746.806911
# std     256.683288   47835.365138
# min       0.000000     406.000000
# 25%       1.000000   41241.500000
# 50%       9.250000   75568.500000
# 75%     105.890000  128483.000000
# max    2125.870000  170348.000000

# %% [markdown]
# # Feature scaling

# %%
from sklearn.preprocessing import StandardScaler, RobustScaler

std_scaler = StandardScaler()
rob_scaler = RobustScaler()

df['amount_scale'] = rob_scaler.fit_transform(df['Amount'].values.reshape(-1,1))
df['time_scale'] = rob_scaler.fit_transform(df['Time'].values.reshape(-1,1))

df.drop(['Time','Amount'], axis=1, inplace=True)

# %%
amount_scale = df['amount_scale']
time_scale = df['time_scale']

df.drop(['amount_scale', 'time_scale'], axis=1, inplace=True)
df.insert(0, 'amount_scale', amount_scale)
df.insert(1, 'time_scale', time_scale)

df.head()
# Out:
#    amount_scale  time_scale        V1        V2        V3        V4        V5  \
# 0      1.783274   -0.994983 -1.359807 -0.072781  2.536347  1.378155 -0.338321
# 1     -0.269825   -0.994983  1.191857  0.266151  0.166480  0.448154  0.060018
# 2      4.983721   -0.994972 -1.358354 -1.340163  1.773209  0.379780 -0.503198
# 3      1.418291   -0.994972 -0.966272 -0.185226  1.792993 -0.863291 -0.010309
# 4      0.670579   -0.994960 -1.158233  0.877737  1.548718  0.403034 -0.407193
#
#          V6        V7        V8  ...       V20       V21       V22       V23  \
# 0  0.462388  0.239599  0.098698  ...  0.251412 -0.018307  0.277838 -0.110474
# 1 -0.082361 -0.078803  0.085102  ... -0.069083 -0.225775 -0.638672  0.101288
# 2  1.800499  0.791461  0.247676  ...  0.524980  0.247998  0.771679  0.909412
# 3  1.247203  0.237609  0.377436  ... -0.208038 -0.108300  0.005274 -0.190321
# 4  0.095921  0.592941 -0.270533  ...  0.408542 -0.009431  0.798278 -0.137458
#
#         V24       V25       V26       V27       V28  Class
# 0  0.066928  0.128539 -0.189115  0.133558 -0.021053      0
# 1 -0.339846  0.167170  0.125895 -0.008983  0.014724      0
# 2 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752      0
# 3 -1.175575  0.647376 -0.221929  0.062723  0.061458      0
# 4  0.141267 -0.206010  0.502292  0.219422  0.215153      0
#
# [5 rows x 31 columns]

# %%
df = df.sample(frac=1)

fraud = df.loc[df['Class'] == 1]
normal = df.loc[df['Class'] == 0][:492]

normal_distributed_data = pd.concat([fraud, normal])

sample_data = normal_distributed_data.sample(frac=1, random_state=42)

sample_data.head()
# Out:
#         amount_scale  time_scale         V1         V2         V3         V4  \
# 137020     -0.027947   -0.031838  -1.275077   0.707994   2.215565   0.032839
# 149869     -0.055893    0.086937  -1.108478   3.448953  -6.216972   3.021052
# 9700        0.237546   -0.825045  -1.046097   0.186320   2.272161  -0.705774
# 44223       1.647453   -0.503307 -19.139733   9.286847 -20.134992   7.818673
# 12261      -0.293440   -0.743348 -17.467710  10.114816 -24.202142  11.805469
#
#                V5        V6         V7        V8  ...       V20       V21  \
# 137020  -0.458892  0.761444  -0.349613  1.023101  ... -0.326630  0.076147
# 149869  -0.529901 -2.551375  -2.001743  1.092432  ... -0.068598  0.825951
# 9700     0.167669 -0.787089   0.142317  0.018832  ...  0.028586  0.113774
# 44223  -15.652208 -1.668348 -21.340478  0.641900  ...  0.427203 -2.182692
# 12261  -10.198046 -2.579938 -17.656788  2.256902  ...  1.001519 -2.328024
#
#              V22       V23       V24       V25       V26       V27       V28  \
# 137020  0.068403 -0.231562 -0.361446  0.332567 -0.453041 -0.039239 -0.011974
# 149869  1.144170  0.208559 -0.295497 -0.690232 -0.364749  0.229327  0.208830
# 9700    0.363189 -0.002094  0.401083 -0.160130  0.878808 -0.043139  0.092289
# 44223   0.520543 -0.760556  0.662767 -0.948454  0.121796 -3.381843 -1.256524
# 12261   0.940830  1.296817 -1.055104  0.111792  0.679695  2.093541 -1.425491
#
#         Class
# 137020      0
# 149869      1
# 9700        0
# 44223       1
# 12261       1
#
# [5 rows x 31 columns]

# %%
X = sample_data.drop('Class', axis=1)
y = sample_data['Class']

# %% [markdown]
# # Train test split

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# # Model selection

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

models = {
    "Logistic Regression": LogisticRegression(),
    "KNN": KNeighborsClassifier(),
    "SVM": SVC(),
    "Random Forest": RandomForestClassifier(),
    "Gradient Boosting": GradientBoostingClassifier()
}

for name, model in models.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    print(f"Model: {name}")
    print(f"Accuracy: {accuracy_score(y_test, y_pred)}")
    print(f"Classification Report:\n{classification_report(y_test, y_pred)}")
    print(f"Confusion Matrix:\n{confusion_matrix(y_test, y_pred)}")
    print()
# Out:
# Model: Logistic Regression
# Accuracy: 0.9493243243243243
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.93      0.96      0.94       134
#            1       0.96      0.94      0.95       162
#
#     accuracy                           0.95       296
#    macro avg       0.95      0.95      0.95       296
# weighted avg       0.95      0.95      0.95       296
#
# Confusion Matrix:
# [[128   6]
#  [  9 153]]
#
# Model: KNN
# Accuracy: 0.9391891891891891
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.92      0.95      0.93       134
#            1       0.96      0.93      0.94       162
#
#     accuracy                           0.94       296
#    macro avg       0.94      0.94      0.94       296
# weighted avg       0.94      0.94      0.94       296
#
# Confusion Matrix:
# [[127   7]
#  [ 11 151]]
#
# Model: SVM
# Accuracy: 0.9493243243243243
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.90      0.99      0.95       134
#            1       0.99      0.91      0.95       162
#
#     accuracy                           0.95       296
#    macro avg       0.95      0.95      0.95       296
# weighted avg       0.95      0.95      0.95       296
#
# Confusion Matrix:
# [[133   1]
#  [ 14 148]]
#
# Model: Random Forest
# Accuracy: 0.9527027027027027
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.92      0.98      0.95       134
#            1       0.98      0.93      0.96       162
#
#     accuracy                           0.95       296
#    macro avg       0.95      0.95      0.95       296
# weighted avg       0.95      0.95      0.95       296
#
# Confusion Matrix:
# [[131   3]
#  [ 11 151]]
#
# Model: Gradient Boosting
# Accuracy: 0.9527027027027027
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.94      0.96      0.95       134
#            1       0.96      0.95      0.96       162
#
#     accuracy                           0.95       296
#    macro avg       0.95      0.95      0.95       296
# weighted avg       0.95      0.95      0.95       296
#
# Confusion Matrix:
# [[128   6]
#  [  8 154]]

# %%
results = pd.DataFrame({
    "Model": list(models.keys()),
    "Accuracy": [accuracy_score(y_test, model.predict(X_test)) for model in models.values()]
})

sns.barplot(x="Model", y="Accuracy", data=results)
plt.xlabel("Model")
plt.ylabel("Accuracy")
plt.title("Model Comparison")
plt.show()

# Compare models using classification reports
results = pd.DataFrame({
    "Model": list(models.keys()),
    "Classification Report": [classification_report(y_test, model.predict(X_test), output_dict=True) for model in models.values()]
})

for i, row in results.iterrows():
    print(f"Model: {row['Model']}")
    print(f"Classification Report:\n{row['Classification Report']}")
    print()

# Compare models using confusion matrices
results = pd.DataFrame({
    "Model": list(models.keys()),
    "Confusion Matrix": [confusion_matrix(y_test, model.predict(X_test)) for model in models.values()]
})

for i, row in results.iterrows():
    print(f"Model: {row['Model']}")
    print(f"Confusion Matrix:\n{row['Confusion Matrix']}")
    print()
# Out:
# Model: Logistic Regression
# Classification Report:
# {'0': {'precision': 0.9343065693430657, 'recall': 0.9552238805970149, 'f1-score': 0.9446494464944649, 'support': 134}, '1': {'precision': 0.9622641509433962, 'recall': 0.9444444444444444, 'f1-score': 0.9532710280373832, 'support': 162}, 'accuracy': 0.9493243243243243, 'macro avg': {'precision': 0.948285360143231, 'recall': 0.9498341625207296, 'f1-score': 0.948960237265924, 'support': 296}, 'weighted avg': {'precision': 0.9496076781918951, 'recall': 0.9493243243243243, 'f1-score': 0.9493680147713324, 'support': 296}}
#
# Model: KNN
# Classification Report:
# {'0': {'precision': 0.9202898550724637, 'recall': 0.9477611940298507, 'f1-score': 0.9338235294117647, 'support': 134}, '1': {'precision': 0.9556962025316456, 'recall': 0.9320987654320988, 'f1-score': 0.9437500000000001, 'support': 162}, 'accuracy': 0.9391891891891891, 'macro avg': {'precision': 0.9379930288020546, 'recall': 0.9399299797309748, 'f1-score': 0.9387867647058824, 'support': 296}, 'weighted avg': {'precision': 0.9396676533440431, 'recall': 0.9391891891891891, 'f1-score': 0.9392562599364072, 'support': 296}}
#
# Model: SVM
# Classification Report:
# {'0': {'precision': 0.9047619047619048, 'recall': 0.9925373134328358, 'f1-score': 0.9466192170818505, 'support': 134}, '1': {'precision': 0.9932885906040269, 'recall': 0.9135802469135802, 'f1-score': 0.9517684887459807, 'support': 162}, 'accuracy': 0.9493243243243243, 'macro avg': {'precision': 0.9490252476829658, 'recall': 0.953058780173208, 'f1-score': 0.9491938529139157, 'support': 296}, 'weighted avg': {'precision': 0.953212320661985, 'recall': 0.9493243243243243, 'f1-score': 0.9494373995466785, 'support': 296}}
#
# Model: Random Forest
# Classification Report:
# {'0': {'precision': 0.9230769230769231, 'recall': 0.9850746268656716, 'f1-score': 0.9530685920577617, 'support': 134}, '1': {'precision': 0.9869281045751634, 'recall': 0.9320987654320988, 'f1-score': 0.9587301587301588, 'support': 162}, 'accuracy': 0.956081081081081, 'macro avg': {'precision': 0.9550025138260433, 'recall': 0.9585866961488851, 'f1-score': 0.9558993753939602, 'support': 296}, 'weighted avg': {'precision': 0.9580225021401492, 'recall': 0.956081081081081, 'f1-score': 0.956167152196033, 'support': 296}}
#
# Model: Gradient Boosting
# Classification Report:
# {'0': {'precision': 0.9411764705882353, 'recall': 0.9552238805970149, 'f1-score': 0.9481481481481482, 'support': 134}, '1': {'precision': 0.9625, 'recall': 0.9506172839506173, 'f1-score': 0.9565217391304348, 'support': 162}, 'accuracy': 0.9527027027027027, 'macro avg': {'precision': 0.9518382352941177, 'recall': 0.952920582273816, 'f1-score': 0.9523349436392915, 'support': 296}, 'weighted avg': {'precision': 0.9528467806041336, 'recall': 0.9527027027027027, 'f1-score': 0.9527309918614266, 'support': 296}}
#
# Model: Logistic Regression
# Confusion Matrix:
# [[128   6]
#  [  9 153]]
#
# Model: KNN
# Confusion Matrix:
# [[127   7]
#  [ 11 151]]
#
# Model: SVM
# Confusion Matrix:
# [[133   1]
#  [ 14 148]]
#
# Model: Random Forest
# Confusion Matrix:
# [[132   2]
#  [ 11 151]]
#
# Model: Gradient Boosting
# Confusion Matrix:
# [[128   6]
#  [  8 154]]

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt


y_pred = RandomForestClassifier().fit(X_train, y_train).predict(X_test)

# Calculate the confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Define labels for the axes
labels = ['Normal', 'Fraud']

# Plot the confusion matrix
fig, ax = plt.subplots(figsize=(5, 5))
sns.heatmap(cm, annot=True, linewidths=0.2, linecolor="black", fmt=".0f", ax=ax)

# Set axis labels and title
ax.set_xlabel('Predicted', fontsize=12)
ax.set_ylabel('True', fontsize=12)
ax.set_xticklabels(labels)
ax.set_yticklabels(labels)
ax.set_title('Confusion Matrix - Random Forest', fontsize=14)
plt.show()
